# %%
import pandas as pd
import numpy as np

# %%
# Import raw data
file_path = r'C:\Users\garov\OneDrive\Documents\GitHub\bavarian-forest-visitor-monitoring-dssgx-24\outputs\Cleaned Data\clean_merged_sensors_data_final.csv'

# Load the Excel file to a data frame
df_mergedsensors = pd.read_csv(file_path)

# Display the first few rows of the DataFrame
df_mergedsensors.head()
# Out:
#             Time  Bayerisch Eisenstein IN  Bayerisch Eisenstein OUT  \
# 0  1/1/2017 0:00                      NaN                       NaN
# 1  1/1/2017 1:00                      NaN                       NaN
# 2  1/1/2017 2:00                      NaN                       NaN
# 3  1/1/2017 3:00                      NaN                       NaN
# 4  1/1/2017 4:00                      NaN                       NaN
#
#    Brechhäuslau IN  Brechhäuslau OUT  Deffernik IN  Deffernik OUT  \
# 0            257.0             412.0           NaN            NaN
# 1              NaN               NaN           NaN            NaN
# 2              NaN               NaN           NaN            NaN
# 3              NaN               NaN           NaN            NaN
# 4              NaN               NaN           NaN            NaN
#
#    Diensthüttenstraße IN  Diensthüttenstraße OUT  Felswandergebiet IN  ...  \
# 0                    NaN                     NaN                  NaN  ...
# 1                    NaN                     NaN                  NaN  ...
# 2                    NaN                     NaN                  NaN  ...
# 3                    NaN                     NaN                  NaN  ...
# 4                    NaN                     NaN                  NaN  ...
#
#    Racheldiensthuette_geoeffnet  Waldschmidthaus_geoeffnet  \
# 0                         False                      469.0
# 1                         False                      469.0
# 2                         False                      469.0
# 3                         False                      469.0
# 4                         False                      469.0
#
#    Falkensteinschutzhaus_geoeffnet  Schwellhaeusl_geoeffnet  Temperatur  \
# 0                             True                     True         0.2
# 1                             True                     True         0.2
# 2                             True                     True         0.2
# 3                             True                     True         0.2
# 4                             True                     True         0.2
#
#    Niederschlagsmenge  Schneehoehe  GS mit  GS max  Total
# 0                 0.0         12.0   59.86   345.0      1
# 1                 0.0         12.0   59.86   345.0      1
# 2                 0.0         12.0   59.86   345.0      1
# 3                 0.0         12.0   59.86   345.0      1
# 4                 0.0         12.0   59.86   345.0      1
#
# [5 rows x 97 columns]

# %%
print(df_mergedsensors.columns.tolist())
# Out:
# ['Time', 'Bayerisch Eisenstein IN', 'Bayerisch Eisenstein OUT', 'Brechhäuslau IN', 'Brechhäuslau OUT', 'Deffernik IN', 'Deffernik OUT', 'Diensthüttenstraße IN', 'Diensthüttenstraße OUT', 'Felswandergebiet IN', 'Felswandergebiet OUT', 'Ferdinandsthal IN', 'Ferdinandsthal OUT', 'Fredenbrücke IN', 'Fredenbrücke OUT', 'Gfäll IN', 'Gfäll OUT', 'Gsenget IN', 'Gsenget OUT', 'Klingenbrunner Wald IN', 'Klingenbrunner Wald OUT', 'Klosterfilz IN', 'Klosterfilz OUT', 'Racheldiensthütte IN', 'Racheldiensthütte OUT', 'Sagwassersäge IN', 'Sagwassersäge OUT', 'Scheuereck IN', 'Scheuereck OUT', 'Schillerstraße IN', 'Schillerstraße OUT', 'Schwarzbachbrücke IN', 'Schwarzbachbrücke OUT', 'Falkenstein 2 OUT', 'Falkenstein 2 IN', 'Lusen 2 IN', 'Lusen 2 OUT', 'Lusen 3 IN', 'Lusen 3 OUT', 'Waldhausreibe IN', 'Waldhausreibe OUT', 'Waldspielgelände IN', 'Waldspielgelände OUT', 'Wistlberg IN', 'Wistlberg OUT', 'Bucina MERGED IN', 'Bucina MERGED OUT', 'Falkenstein 1 MERGED IN', 'Falkenstein 1 MERGED OUT', 'Lusen 1 MERGED IN', 'Lusen 1 MERGED OUT', 'Trinkwassertalsperre MERGED IN', 'Trinkwassertalsperre MERGED OUT', 'traffic', 'sum_IN', 'sum_OUT', 'diff', 'occupancy', 'Unnamed: 0.1', 'Unnamed: 0', 'Temperature (°C)', 'Relative Humidity (%)', 'Precipitation (mm)', 'Wind Speed (km/h)', 'Sunshine Duration (min)', 'Tag', 'Monat', 'Jahr', 'Wochentag', 'Wochenende', 'Jahreszeit', 'Laubfärbung', 'Besuchszahlen_HEH', 'Besuchszahlen_HZW', 'Besuchszahlen_WGM', 'Parkpl_HEH_PKW', 'Parkpl_HEH_BUS', 'Parkpl_HZW_PKW', 'Parkpl_HZW_BUS', 'Schulferien_Bayern', 'Schulferien_CZ', 'Feiertag_Bayern', 'Feiertag_CZ', 'HEH_geoeffnet', 'HZW_geoeffnet', 'WGM_geoeffnet', 'Lusenschutzhaus_geoeffnet', 'Racheldiensthuette_geoeffnet', 'Waldschmidthaus_geoeffnet', 'Falkensteinschutzhaus_geoeffnet', 'Schwellhaeusl_geoeffnet', 'Temperatur', 'Niederschlagsmenge', 'Schneehoehe', 'GS mit', 'GS max', 'Total']

# %%
# Reorder columns so Falkenstein 2 IN is before Falkenstein 2 Out
df_mergedsensors = df_mergedsensors[['Time', 'Bayerisch Eisenstein IN', 'Bayerisch Eisenstein OUT', 
                                      'Brechhäuslau IN', 'Brechhäuslau OUT', 'Deffernik IN', 'Deffernik OUT', 
                                      'Diensthüttenstraße IN', 'Diensthüttenstraße OUT', 'Felswandergebiet IN', 
                                      'Felswandergebiet OUT', 'Ferdinandsthal IN', 'Ferdinandsthal OUT', 'Fredenbrücke IN', 
                                      'Fredenbrücke OUT', 'Gfäll IN', 'Gfäll OUT', 'Gsenget IN', 'Gsenget OUT', 'Klingenbrunner Wald IN', 
                                      'Klingenbrunner Wald OUT', 'Klosterfilz IN', 'Klosterfilz OUT', 'Racheldiensthütte IN', 
                                      'Racheldiensthütte OUT', 'Sagwassersäge IN', 'Sagwassersäge OUT', 'Scheuereck IN', 
                                      'Scheuereck OUT', 'Schillerstraße IN', 'Schillerstraße OUT', 'Schwarzbachbrücke IN', 
                                      'Schwarzbachbrücke OUT', 'Falkenstein 2 IN', 'Falkenstein 2 OUT', 'Lusen 2 IN', 'Lusen 2 OUT', 
                                      'Lusen 3 IN', 'Lusen 3 OUT', 'Waldhausreibe IN', 'Waldhausreibe OUT', 'Waldspielgelände IN', 
                                      'Waldspielgelände OUT', 'Wistlberg IN', 'Wistlberg OUT', 'Bucina MERGED IN', 'Bucina MERGED OUT', 
                                      'Falkenstein 1 MERGED IN', 'Falkenstein 1 MERGED OUT', 'Lusen 1 MERGED IN', 'Lusen 1 MERGED OUT', 
                                      'Trinkwassertalsperre MERGED IN', 'Trinkwassertalsperre MERGED OUT', 'traffic', 
                                      'sum_IN', 'sum_OUT', 'diff', 'occupancy', 'Unnamed: 0.1', 'Unnamed: 0', 'Temperature (°C)', 
                                      'Relative Humidity (%)', 'Precipitation (mm)', 'Wind Speed (km/h)', 'Sunshine Duration (min)', 
                                      'Tag', 'Monat', 'Jahr', 'Wochentag', 'Wochenende', 'Jahreszeit', 'Laubfärbung', 
                                      'Besuchszahlen_HEH', 'Besuchszahlen_HZW', 'Besuchszahlen_WGM', 'Parkpl_HEH_PKW', 
                                      'Parkpl_HEH_BUS', 'Parkpl_HZW_PKW', 'Parkpl_HZW_BUS', 'Schulferien_Bayern', 
                                      'Schulferien_CZ', 'Feiertag_Bayern', 'Feiertag_CZ', 'HEH_geoeffnet', 'HZW_geoeffnet', 
                                      'WGM_geoeffnet', 'Lusenschutzhaus_geoeffnet', 'Racheldiensthuette_geoeffnet', 
                                      'Waldschmidthaus_geoeffnet', 'Falkensteinschutzhaus_geoeffnet', 'Schwellhaeusl_geoeffnet', 
                                      'Temperatur', 'Niederschlagsmenge', 'Schneehoehe', 'GS mit', 'GS max', 'Total']]

# %%
# Remove MERGED from column names with this unnecessary label
df_mergedsensors.columns = df_mergedsensors.columns.str.replace(' MERGED', '', regex=False)

# %%
print(df_mergedsensors.columns.tolist())
# Out:
# ['Time', 'Bayerisch Eisenstein IN', 'Bayerisch Eisenstein OUT', 'Brechhäuslau IN', 'Brechhäuslau OUT', 'Deffernik IN', 'Deffernik OUT', 'Diensthüttenstraße IN', 'Diensthüttenstraße OUT', 'Felswandergebiet IN', 'Felswandergebiet OUT', 'Ferdinandsthal IN', 'Ferdinandsthal OUT', 'Fredenbrücke IN', 'Fredenbrücke OUT', 'Gfäll IN', 'Gfäll OUT', 'Gsenget IN', 'Gsenget OUT', 'Klingenbrunner Wald IN', 'Klingenbrunner Wald OUT', 'Klosterfilz IN', 'Klosterfilz OUT', 'Racheldiensthütte IN', 'Racheldiensthütte OUT', 'Sagwassersäge IN', 'Sagwassersäge OUT', 'Scheuereck IN', 'Scheuereck OUT', 'Schillerstraße IN', 'Schillerstraße OUT', 'Schwarzbachbrücke IN', 'Schwarzbachbrücke OUT', 'Falkenstein 2 IN', 'Falkenstein 2 OUT', 'Lusen 2 IN', 'Lusen 2 OUT', 'Lusen 3 IN', 'Lusen 3 OUT', 'Waldhausreibe IN', 'Waldhausreibe OUT', 'Waldspielgelände IN', 'Waldspielgelände OUT', 'Wistlberg IN', 'Wistlberg OUT', 'Bucina IN', 'Bucina OUT', 'Falkenstein 1 IN', 'Falkenstein 1 OUT', 'Lusen 1 IN', 'Lusen 1 OUT', 'Trinkwassertalsperre IN', 'Trinkwassertalsperre OUT', 'traffic', 'sum_IN', 'sum_OUT', 'diff', 'occupancy', 'Unnamed: 0.1', 'Unnamed: 0', 'Temperature (°C)', 'Relative Humidity (%)', 'Precipitation (mm)', 'Wind Speed (km/h)', 'Sunshine Duration (min)', 'Tag', 'Monat', 'Jahr', 'Wochentag', 'Wochenende', 'Jahreszeit', 'Laubfärbung', 'Besuchszahlen_HEH', 'Besuchszahlen_HZW', 'Besuchszahlen_WGM', 'Parkpl_HEH_PKW', 'Parkpl_HEH_BUS', 'Parkpl_HZW_PKW', 'Parkpl_HZW_BUS', 'Schulferien_Bayern', 'Schulferien_CZ', 'Feiertag_Bayern', 'Feiertag_CZ', 'HEH_geoeffnet', 'HZW_geoeffnet', 'WGM_geoeffnet', 'Lusenschutzhaus_geoeffnet', 'Racheldiensthuette_geoeffnet', 'Waldschmidthaus_geoeffnet', 'Falkensteinschutzhaus_geoeffnet', 'Schwellhaeusl_geoeffnet', 'Temperatur', 'Niederschlagsmenge', 'Schneehoehe', 'GS mit', 'GS max', 'Total']

# %%
df_mergedsensors.head()
# Out:
#             Time  Bayerisch Eisenstein IN  Bayerisch Eisenstein OUT  \
# 0  1/1/2017 0:00                      NaN                       NaN
# 1  1/1/2017 1:00                      NaN                       NaN
# 2  1/1/2017 2:00                      NaN                       NaN
# 3  1/1/2017 3:00                      NaN                       NaN
# 4  1/1/2017 4:00                      NaN                       NaN
#
#    Brechhäuslau IN  Brechhäuslau OUT  Deffernik IN  Deffernik OUT  \
# 0            257.0             412.0           NaN            NaN
# 1              NaN               NaN           NaN            NaN
# 2              NaN               NaN           NaN            NaN
# 3              NaN               NaN           NaN            NaN
# 4              NaN               NaN           NaN            NaN
#
#    Diensthüttenstraße IN  Diensthüttenstraße OUT  Felswandergebiet IN  ...  \
# 0                    NaN                     NaN                  NaN  ...
# 1                    NaN                     NaN                  NaN  ...
# 2                    NaN                     NaN                  NaN  ...
# 3                    NaN                     NaN                  NaN  ...
# 4                    NaN                     NaN                  NaN  ...
#
#    Racheldiensthuette_geoeffnet  Waldschmidthaus_geoeffnet  \
# 0                         False                      469.0
# 1                         False                      469.0
# 2                         False                      469.0
# 3                         False                      469.0
# 4                         False                      469.0
#
#    Falkensteinschutzhaus_geoeffnet  Schwellhaeusl_geoeffnet  Temperatur  \
# 0                             True                     True         0.2
# 1                             True                     True         0.2
# 2                             True                     True         0.2
# 3                             True                     True         0.2
# 4                             True                     True         0.2
#
#    Niederschlagsmenge  Schneehoehe  GS mit  GS max  Total
# 0                 0.0         12.0   59.86   345.0      1
# 1                 0.0         12.0   59.86   345.0      1
# 2                 0.0         12.0   59.86   345.0      1
# 3                 0.0         12.0   59.86   345.0      1
# 4                 0.0         12.0   59.86   345.0      1
#
# [5 rows x 97 columns]

# %%
columns_to_drop = ['traffic', 'sum_IN', 'sum_OUT', 'diff', 'occupancy', 'Unnamed: 0.1', 'Unnamed: 0', 'Total']
df_mergedsensors = df_mergedsensors.drop(columns=columns_to_drop)

# %%
# Ensure the 'Time' column is in datetime format
df_mergedsensors['Time'] = pd.to_datetime(df_mergedsensors['Time'])

# List of sensor columns to melt
sensor_columns = [
    'Bayerisch Eisenstein', 'Brechhäuslau', 'Bucina', 'Deffernik',
    'Diensthüttenstraße', 'Falkenstein 1', 'Falkenstein 2',
    'Felswandergebiet', 'Ferdinandsthal', 'Fredenbrücke', 'Gfäll',
    'Gsenget', 'Klingenbrunner Wald', 'Klosterfilz', 'Lusen 1',
    'Lusen 2', 'Lusen 3', 'Racheldiensthütte', 'Sagwassersäge',
    'Scheuereck', 'Schillerstraße', 'Schwarzbachbrücke',
    'Trinkwassertalsperre', 'Waldhausreibe', 'Waldspielgelände',
    'Wistlberg'
]

# Create a list of columns for melting, including IN/OUT directions for each sensor
melt_columns = [f'{sensor} IN' for sensor in sensor_columns] + [f'{sensor} OUT' for sensor in sensor_columns]

# Melt the DataFrame, excluding weather and other non-sensor columns
df_melted = df_mergedsensors.melt(
    id_vars=[
        'Time', 'Temperature (°C)', 'Relative Humidity (%)', 'Precipitation (mm)', 
        'Wind Speed (km/h)', 'Sunshine Duration (min)', 'Tag', 'Monat', 'Jahr', 
        'Wochentag', 'Wochenende', 'Jahreszeit', 'Laubfärbung', 'Besuchszahlen_HEH', 
        'Besuchszahlen_HZW', 'Besuchszahlen_WGM', 'Parkpl_HEH_PKW', 'Parkpl_HEH_BUS', 
        'Parkpl_HZW_PKW', 'Parkpl_HZW_BUS', 'Schulferien_Bayern', 'Schulferien_CZ', 
        'Feiertag_Bayern', 'Feiertag_CZ', 'HEH_geoeffnet', 'HZW_geoeffnet', 'WGM_geoeffnet', 
        'Lusenschutzhaus_geoeffnet', 'Racheldiensthuette_geoeffnet', 'Waldschmidthaus_geoeffnet', 
        'Falkensteinschutzhaus_geoeffnet', 'Schwellhaeusl_geoeffnet', 'Temperatur', 
        'Niederschlagsmenge', 'Schneehoehe', 'GS mit', 'GS max'
    ],
    value_vars=melt_columns,
    var_name='Sensor_Direction',
    value_name='Count'
)

# Split the Sensor_Direction into separate Sensor Name and Direction columns
df_melted[['Sensor', 'Direction']] = df_melted['Sensor_Direction'].str.rsplit(' ', n=1, expand=True)
df_melted.drop(columns=['Sensor_Direction'], inplace=True)

# Extract hour from the 'Time' column
df_melted['Hour'] = df_melted['Time'].dt.hour

# Pivot the DataFrame to have 'IN' and 'OUT' as separate columns, while retaining hour in the rows
df_pivot = df_melted.pivot_table(
    index=['Time', 'Sensor', 'Hour'], 
    columns='Direction', 
    values='Count',
    aggfunc='sum'
).reset_index()

# Merge the original non-sensor columns back to the pivoted DataFrame
# Exclude the columns that have been pivoted to avoid duplication
non_sensor_columns = [
    'Time', 'Temperature (°C)', 'Relative Humidity (%)', 'Precipitation (mm)', 
    'Wind Speed (km/h)', 'Sunshine Duration (min)', 'Tag', 'Monat', 'Jahr', 
    'Wochentag', 'Wochenende', 'Jahreszeit', 'Laubfärbung', 'Besuchszahlen_HEH', 
    'Besuchszahlen_HZW', 'Besuchszahlen_WGM', 'Parkpl_HEH_PKW', 'Parkpl_HEH_BUS', 
    'Parkpl_HZW_PKW', 'Parkpl_HZW_BUS', 'Schulferien_Bayern', 'Schulferien_CZ', 
    'Feiertag_Bayern', 'Feiertag_CZ', 'HEH_geoeffnet', 'HZW_geoeffnet', 'WGM_geoeffnet', 
    'Lusenschutzhaus_geoeffnet', 'Racheldiensthuette_geoeffnet', 'Waldschmidthaus_geoeffnet', 
    'Falkensteinschutzhaus_geoeffnet', 'Schwellhaeusl_geoeffnet', 'Temperatur', 
    'Niederschlagsmenge', 'Schneehoehe', 'GS mit', 'GS max'
]

# Merge back the non-sensor columns using 'Time' as the key
df_final = pd.merge(df_pivot, df_mergedsensors[non_sensor_columns], on='Time', how='left')

# %%
# Rename columns by specifying the new names
df_final = df_final.rename(columns={
    'Temperature (°C)': 'Temperature',
    'Relative Humidity (%)': 'Relative Humidity',
    'Precipitation (mm)': 'Precipitation',
    'Wind Speed (km/h)': 'Wind Speed',
    'Sunshine Duration (min)': 'Sunshine Duration'
})

# Print the renamed columns to verify
print(df_final.columns)
# Out:
# Index(['Time', 'Sensor', 'Hour', 'IN', 'OUT', 'Temperature',
#        'Relative Humidity', 'Precipitation', 'Wind Speed', 'Sunshine Duration',
#        'Tag', 'Monat', 'Jahr', 'Wochentag', 'Wochenende', 'Jahreszeit',
#        'Laubfärbung', 'Besuchszahlen_HEH', 'Besuchszahlen_HZW',
#        'Besuchszahlen_WGM', 'Parkpl_HEH_PKW', 'Parkpl_HEH_BUS',
#        'Parkpl_HZW_PKW', 'Parkpl_HZW_BUS', 'Schulferien_Bayern',
#        'Schulferien_CZ', 'Feiertag_Bayern', 'Feiertag_CZ', 'HEH_geoeffnet',
#        'HZW_geoeffnet', 'WGM_geoeffnet', 'Lusenschutzhaus_geoeffnet',
#        'Racheldiensthuette_geoeffnet', 'Waldschmidthaus_geoeffnet',
#        'Falkensteinschutzhaus_geoeffnet', 'Schwellhaeusl_geoeffnet',
#        'Temperatur', 'Niederschlagsmenge', 'Schneehoehe', 'GS mit', 'GS max'],
#       dtype='object')

# %%
df_final.tail(5)
# Out:
#                        Time                Sensor  Hour   IN  OUT  \
# 1739707 2024-08-19 23:00:00     Schwarzbachbrücke    23  0.0  0.0
# 1739708 2024-08-19 23:00:00  Trinkwassertalsperre    23  0.0  0.0
# 1739709 2024-08-19 23:00:00         Waldhausreibe    23  0.0  0.0
# 1739710 2024-08-19 23:00:00      Waldspielgelände    23  0.0  0.0
# 1739711 2024-08-19 23:00:00             Wistlberg    23  0.0  0.0
#
#          Temperature  Relative Humidity  Precipitation  Wind Speed  \
# 1739707         16.3                 83            0.0         9.4
# 1739708         16.3                 83            0.0         9.4
# 1739709         16.3                 83            0.0         9.4
# 1739710         16.3                 83            0.0         9.4
# 1739711         16.3                 83            0.0         9.4
#
#          Sunshine Duration  ...  Lusenschutzhaus_geoeffnet  \
# 1739707                  0  ...                       True
# 1739708                  0  ...                       True
# 1739709                  0  ...                       True
# 1739710                  0  ...                       True
# 1739711                  0  ...                       True
#
#          Racheldiensthuette_geoeffnet  Waldschmidthaus_geoeffnet  \
# 1739707                          True                        NaN
# 1739708                          True                        NaN
# 1739709                          True                        NaN
# 1739710                          True                        NaN
# 1739711                          True                        NaN
#
#         Falkensteinschutzhaus_geoeffnet  Schwellhaeusl_geoeffnet Temperatur  \
# 1739707                            True                     True        NaN
# 1739708                            True                     True        NaN
# 1739709                            True                     True        NaN
# 1739710                            True                     True        NaN
# 1739711                            True                     True        NaN
#
#          Niederschlagsmenge  Schneehoehe  GS mit  GS max
# 1739707                 NaN          NaN     NaN     NaN
# 1739708                 NaN          NaN     NaN     NaN
# 1739709                 NaN          NaN     NaN     NaN
# 1739710                 NaN          NaN     NaN     NaN
# 1739711                 NaN          NaN     NaN     NaN
#
# [5 rows x 41 columns]

# %%
print(df_final.shape)
# Out:
# (1739712, 41)

# %%
print(df_final.columns.tolist())
# Out:
# ['Time', 'Sensor', 'Hour', 'IN', 'OUT', 'Temperature', 'Relative Humidity', 'Precipitation', 'Wind Speed', 'Sunshine Duration', 'Tag', 'Monat', 'Jahr', 'Wochentag', 'Wochenende', 'Jahreszeit', 'Laubfärbung', 'Besuchszahlen_HEH', 'Besuchszahlen_HZW', 'Besuchszahlen_WGM', 'Parkpl_HEH_PKW', 'Parkpl_HEH_BUS', 'Parkpl_HZW_PKW', 'Parkpl_HZW_BUS', 'Schulferien_Bayern', 'Schulferien_CZ', 'Feiertag_Bayern', 'Feiertag_CZ', 'HEH_geoeffnet', 'HZW_geoeffnet', 'WGM_geoeffnet', 'Lusenschutzhaus_geoeffnet', 'Racheldiensthuette_geoeffnet', 'Waldschmidthaus_geoeffnet', 'Falkensteinschutzhaus_geoeffnet', 'Schwellhaeusl_geoeffnet', 'Temperatur', 'Niederschlagsmenge', 'Schneehoehe', 'GS mit', 'GS max']

# %%
df_final['Time'].max()
# Out:
# Timestamp('2024-08-19 23:00:00')

# %%
# Create Sensor_loc variable

# Create a dictionary for mapping
location_mapping = {
    'Bayerisch Eisenstein': 'North', 'Brechhäuslau': 'North', 'Deffernik': 'North', 
    'Falkenstein 1': 'North', 'Falkenstein 2': 'North', 'Ferdinandsthal': 'North', 
    'Gsenget': 'North', 'Scheuereck': 'North', 'Schillerstraße': 'North', 
    'Trinkwassertalsperre': 'North', 'Bucina': 'South', 'Diensthüttenstraße': 'South', 
    'Felswandergebiet': 'South', 'Fredenbrücke': 'South', 'Gfäll': 'South', 
    'Klingenbrunner Wald': 'South', 'Klosterfilz': 'South', 'Lusen 1': 'South', 
    'Lusen 2': 'South', 'Lusen 3': 'South', 'Racheldiensthütte': 'South', 
    'Schwarzbachbrücke': 'South', 'Waldhausreibe': 'South', 'Waldspielgelände': 'South', 
    'Wistlberg': 'South', 'Sagwassersäge': 'South'
}

# Assign values to the new column 'Sensor_loc'
df_final['Sensor_loc'] = df_final['Sensor'].map(location_mapping)

# %%
# Create Traffic Absolute Variable
df_final['Traffic_ABS'] = df_final['IN'] + df_final['OUT']

# %%
df_final.head()
# Out:
#         Time                Sensor  Hour     IN    OUT  Temperature  \
# 0 2017-01-01  Bayerisch Eisenstein     0    0.0    0.0         -7.8
# 1 2017-01-01          Brechhäuslau     0  257.0  412.0         -7.8
# 2 2017-01-01                Bucina     0    0.0    0.0         -7.8
# 3 2017-01-01             Deffernik     0    0.0    0.0         -7.8
# 4 2017-01-01    Diensthüttenstraße     0    0.0    0.0         -7.8
#
#    Relative Humidity  Precipitation  Wind Speed  Sunshine Duration  ...  \
# 0                100            0.0         2.9                  0  ...
# 1                100            0.0         2.9                  0  ...
# 2                100            0.0         2.9                  0  ...
# 3                100            0.0         2.9                  0  ...
# 4                100            0.0         2.9                  0  ...
#
#    Waldschmidthaus_geoeffnet  Falkensteinschutzhaus_geoeffnet  \
# 0                      469.0                             True
# 1                      469.0                             True
# 2                      469.0                             True
# 3                      469.0                             True
# 4                      469.0                             True
#
#    Schwellhaeusl_geoeffnet Temperatur  Niederschlagsmenge Schneehoehe  GS mit  \
# 0                     True        0.2                 0.0        12.0   59.86
# 1                     True        0.2                 0.0        12.0   59.86
# 2                     True        0.2                 0.0        12.0   59.86
# 3                     True        0.2                 0.0        12.0   59.86
# 4                     True        0.2                 0.0        12.0   59.86
#
#    GS max  Sensor_loc  Traffic_ABS
# 0   345.0       North          0.0
# 1   345.0       North        669.0
# 2   345.0       South          0.0
# 3   345.0       North          0.0
# 4   345.0       South          0.0
#
# [5 rows x 43 columns]

# %%
df_final.head()
# Out:
#         Time                Sensor  Hour     IN    OUT  Temperature  \
# 0 2017-01-01  Bayerisch Eisenstein     0    0.0    0.0         -7.8
# 1 2017-01-01          Brechhäuslau     0  257.0  412.0         -7.8
# 2 2017-01-01                Bucina     0    0.0    0.0         -7.8
# 3 2017-01-01             Deffernik     0    0.0    0.0         -7.8
# 4 2017-01-01    Diensthüttenstraße     0    0.0    0.0         -7.8
#
#    Relative Humidity  Precipitation  Wind Speed  Sunshine Duration  ...  \
# 0                100            0.0         2.9                  0  ...
# 1                100            0.0         2.9                  0  ...
# 2                100            0.0         2.9                  0  ...
# 3                100            0.0         2.9                  0  ...
# 4                100            0.0         2.9                  0  ...
#
#    Waldschmidthaus_geoeffnet  Falkensteinschutzhaus_geoeffnet  \
# 0                      469.0                             True
# 1                      469.0                             True
# 2                      469.0                             True
# 3                      469.0                             True
# 4                      469.0                             True
#
#    Schwellhaeusl_geoeffnet Temperatur  Niederschlagsmenge Schneehoehe  GS mit  \
# 0                     True        0.2                 0.0        12.0   59.86
# 1                     True        0.2                 0.0        12.0   59.86
# 2                     True        0.2                 0.0        12.0   59.86
# 3                     True        0.2                 0.0        12.0   59.86
# 4                     True        0.2                 0.0        12.0   59.86
#
#    GS max  Sensor_loc  Traffic_ABS
# 0   345.0       North          0.0
# 1   345.0       North        669.0
# 2   345.0       South          0.0
# 3   345.0       North          0.0
# 4   345.0       South          0.0
#
# [5 rows x 43 columns]

# %%
df_final_sub = df_final[df_final['Jahr'].isin([2023, 2024])].copy()

# %%
# Calculate min and max values of Traffic_ABS in df_final_filtered
min_value = df_final_sub['Traffic_ABS'].min()
max_value = df_final_sub['Traffic_ABS'].max()

# Apply min-max normalization to create the Traffic_NORM column
df_final_sub['Traffic_NORM'] = (df_final_sub['Traffic_ABS'] - min_value) / (max_value - min_value)

# %%
df_final_sub['Pred_Traffic_ABS'] = pd.NA
df_final_sub['Pred_Traffic_NORM'] = pd.NA

# %%
df_final_sub.head()
# Out:
#               Time                Sensor  Hour   IN  OUT  Temperature  \
# 1367184 2023-01-01  Bayerisch Eisenstein     0  0.0  0.0          6.4
# 1367185 2023-01-01          Brechhäuslau     0  0.0  0.0          6.4
# 1367186 2023-01-01                Bucina     0  0.0  0.0          6.4
# 1367187 2023-01-01             Deffernik     0  0.0  0.0          6.4
# 1367188 2023-01-01    Diensthüttenstraße     0  0.0  0.0          6.4
#
#          Relative Humidity  Precipitation  Wind Speed  Sunshine Duration  ...  \
# 1367184                 82            0.0         9.0                  0  ...
# 1367185                 82            0.0         9.0                  0  ...
# 1367186                 82            0.0         9.0                  0  ...
# 1367187                 82            0.0         9.0                  0  ...
# 1367188                 82            0.0         9.0                  0  ...
#
#          Temperatur  Niederschlagsmenge  Schneehoehe     GS mit  GS max  \
# 1367184    9.278472                 0.0          0.0  54.652778   338.0
# 1367185    9.278472                 0.0          0.0  54.652778   338.0
# 1367186    9.278472                 0.0          0.0  54.652778   338.0
# 1367187    9.278472                 0.0          0.0  54.652778   338.0
# 1367188    9.278472                 0.0          0.0  54.652778   338.0
#
#         Sensor_loc  Traffic_ABS  Traffic_NORM  Pred_Traffic_ABS  \
# 1367184      North          0.0           0.0              <NA>
# 1367185      North          0.0           0.0              <NA>
# 1367186      South          0.0           0.0              <NA>
# 1367187      North          0.0           0.0              <NA>
# 1367188      South          0.0           0.0              <NA>
#
#          Pred_Traffic_NORM
# 1367184               <NA>
# 1367185               <NA>
# 1367186               <NA>
# 1367187               <NA>
# 1367188               <NA>
#
# [5 rows x 46 columns]

# %%
print(df_final_sub.columns)
# Out:
# Index(['Time', 'Sensor', 'Hour', 'IN', 'OUT', 'Temperature',
#        'Relative Humidity', 'Precipitation', 'Wind Speed', 'Sunshine Duration',
#        'Tag', 'Monat', 'Jahr', 'Wochentag', 'Wochenende', 'Jahreszeit',
#        'Laubfärbung', 'Besuchszahlen_HEH', 'Besuchszahlen_HZW',
#        'Besuchszahlen_WGM', 'Parkpl_HEH_PKW', 'Parkpl_HEH_BUS',
#        'Parkpl_HZW_PKW', 'Parkpl_HZW_BUS', 'Schulferien_Bayern',
#        'Schulferien_CZ', 'Feiertag_Bayern', 'Feiertag_CZ', 'HEH_geoeffnet',
#        'HZW_geoeffnet', 'WGM_geoeffnet', 'Lusenschutzhaus_geoeffnet',
#        'Racheldiensthuette_geoeffnet', 'Waldschmidthaus_geoeffnet',
#        'Falkensteinschutzhaus_geoeffnet', 'Schwellhaeusl_geoeffnet',
#        'Temperatur', 'Niederschlagsmenge', 'Schneehoehe', 'GS mit', 'GS max',
#        'Sensor_loc', 'Traffic_ABS', 'Traffic_NORM', 'Pred_Traffic_ABS',
#        'Pred_Traffic_NORM'],
#       dtype='object')

# %%
df_final_sub['Wochentag'] = df_final_sub['Wochentag'].astype('category')
df_final_sub['Jahreszeit'] = df_final_sub['Jahreszeit'].astype('category')
df_final_sub['Schulferien_CZ'] = df_final_sub['Jahreszeit'].astype('bool')

# %%
# Replace spaces in column names with underscores
df_final_sub.columns = df_final_sub.columns.str.replace(' ', '_')

# %%
from sklearn.preprocessing import StandardScaler
import statsmodels.api as sm
import statsmodels.formula.api as smf
from sklearn.metrics import mean_squared_error, r2_score

# %%
# Define the mapping from German days to numbers
day_mapping = {
    'Sonntag': 1,
    'Montag': 2,
    'Dienstag': 3,
    'Mittwoch': 4,
    'Donnerstag': 5,
    'Freitag': 6,
    'Samstag': 7
}

# Apply the mapping to the Wochentag column
df_final_sub['Wochentag'] = df_final_sub['Wochentag'].map(day_mapping)

# %%
for column in df_final_sub.columns:
    # Check if the column's data type is bool
    if df_final_sub[column].dtype == 'bool':
        # Convert True/False to 1/0
        df_final_sub[column] = df_final_sub[column].astype(int)

# %%
# Define the mapping from German days to numbers
season_mapping = {
    'Winter': 1,
    'Frühling': 2,
    'Sommer': 3,
    'Herbst': 4
}

# Apply the mapping to the Wochentag column
df_final_sub['Jahreszeit'] = df_final_sub['Jahreszeit'].map(season_mapping)

# %%
print(df_final_sub.dtypes)
# Out:
# Time                               datetime64[ns]
# Sensor                                     object
# Hour                                        int32
# IN                                        float64
# OUT                                       float64
# Temperature                               float64
# Relative_Humidity                           int64
# Precipitation                             float64
# Wind_Speed                                float64
# Sunshine_Duration                           int64
# Tag                                         int64
# Monat                                       int64
# Jahr                                        int64
# Wochentag                                category
# Wochenende                                  int32
# Jahreszeit                               category
# Laubfärbung                                 int32
# Besuchszahlen_HEH                         float64
# Besuchszahlen_HZW                         float64
# Besuchszahlen_WGM                         float64
# Parkpl_HEH_PKW                            float64
# Parkpl_HEH_BUS                            float64
# Parkpl_HZW_PKW                            float64
# Parkpl_HZW_BUS                            float64
# Schulferien_Bayern                          int32
# Schulferien_CZ                              int32
# Feiertag_Bayern                             int32
# Feiertag_CZ                                 int32
# HEH_geoeffnet                               int32
# HZW_geoeffnet                               int32
# WGM_geoeffnet                               int32
# Lusenschutzhaus_geoeffnet                   int32
# Racheldiensthuette_geoeffnet                int32
# Waldschmidthaus_geoeffnet                 float64
# Falkensteinschutzhaus_geoeffnet             int32
# Schwellhaeusl_geoeffnet                     int32
# Temperatur                                float64
# Niederschlagsmenge                        float64
# Schneehoehe                               float64
# GS_mit                                    float64
# GS_max                                    float64
# Sensor_loc                                 object
# Traffic_ABS                               float64
# Traffic_NORM                              float64
# Pred_Traffic_ABS                           object
# Pred_Traffic_NORM                          object
# dtype: object

# %%
# Convert boolean features to integer (True=1, False=0)
for bool_feature in bool_features:
    data[bool_feature] = data[bool_feature].astype(int)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[818], line 3
#       1 # Convert boolean features to integer (True=1, False=0)
#       2 for bool_feature in bool_features:
# ----> 3     data[bool_feature] = data[bool_feature].astype(int)
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
# Split the data based on 'Jahr'
train_data = df_final_sub[df_final_sub['Jahr'] == 2023]
test_data = df_final_sub[df_final_sub['Jahr'] == 2024]

# Define the features and target variable
numeric_features = [
    'Temperature',
    'Relative_Humidity',
    'Precipitation',
    'Wind_Speed',
    'Sunshine_Duration',
]

# Identify categorical features
categorical_features = [
    'Monat', 'Wochentag', 'Jahreszeit'
]

# Identify bool features
bool_features = [
    'Wochenende', 'Laubfärbung', 'Schulferien_Bayern', 'Schulferien_CZ', 'Feiertag_Bayern', 'Feiertag_CZ',
    'HEH_geoeffnet', 'HZW_geoeffnet', 'WGM_geoeffnet', 'Lusenschutzhaus_geoeffnet',
    'Racheldiensthuette_geoeffnet', 'Falkensteinschutzhaus_geoeffnet', 'Schwellhaeusl_geoeffnet', 'Schulferien_CZ'
]

target = 'Traffic_ABS'

# %%
formula = "Traffic_ABS ~ Temperature + Relative_Humidity + Precipitation + Wind_Speed + Sunshine_Duration + Wochenende"

# %%
import pandas as pd
import statsmodels.api as sm
from statsmodels.formula.api import mixedlm
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer

# Load your data into df_final_sub
# df_final_sub = pd.read_csv('your_data.csv')

# Split the data based on 'Jahr'
train_data = df_final_sub[df_final_sub['Jahr'] == 2023]
test_data = df_final_sub[df_final_sub['Jahr'] == 2024]

# Define features and target
numeric_features = [
    'Temperature',
    'Relative_Humidity',
    'Precipitation',
    'Wind_Speed',
    'Sunshine_Duration',
]

categorical_features = [
    'Monat', 'Wochentag', 'Jahreszeit'
]

bool_features = [
    'Wochenende', 'Laubfärbung', 'Schulferien_Bayern', 'Schulferien_CZ', 'Feiertag_Bayern', 'Feiertag_CZ',
    'HEH_geoeffnet', 'HZW_geoeffnet', 'WGM_geoeffnet', 'Lusenschutzhaus_geoeffnet',
    'Racheldiensthuette_geoeffnet', 'Falkensteinschutzhaus_geoeffnet', 'Schwellhaeusl_geoeffnet', 'Schulferien_CZ'
]

target = 'Traffic_ABS'

# Combine all features
all_features = numeric_features + categorical_features + bool_features

# Preprocessing pipeline
preprocessor = ColumnTransformer(
    transformers=[
        ('num', Pipeline(steps=[
            ('imputer', SimpleImputer(strategy='mean')),
            ('scaler', StandardScaler())
        ]), numeric_features),
        ('cat', OneHotEncoder(drop='first'), categorical_features),
        ('bool', 'passthrough', bool_features)
    ]
)

# Prepare training data
X_train = train_data[all_features]
y_train = train_data[target]

# Transform features
X_train_transformed = preprocessor.fit_transform(X_train)

# Create a DataFrame with transformed features
X_train_transformed_df = pd.DataFrame(X_train_transformed)

# Define the mixed effects model
# Assuming random intercepts for 'Jahr' as an example
model = mixedlm(f"{target} ~ {' + '.join(numeric_features + bool_features)}", 
                 train_data,
                 groups=train_data["Sensor"],
                 re_formula="~1",
                 vc_formula={"Sensor": "0 + C(Sensor)"})

# Fit the model
result = model.fit()

# Print the summary of the model
print(result.summary())

# Prepare test data similarly
X_test = test_data[all_features]
y_test = test_data[target]
X_test_transformed = preprocessor.transform(X_test)
X_test_transformed_df = pd.DataFrame(X_test_transformed)

# Make predictions (if needed)
# predictions = result.predict(X_test_transformed_df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[817], line 58
#      55 y_train = train_data[target]
#      57 # Transform features
# ---> 58 X_train_transformed = preprocessor.fit_transform(X_train)
#      60 # Create a DataFrame with transformed features
#      61 X_train_transformed_df = pd.DataFrame(X_train_transformed)
#
# File c:\Users\garov\.pyenv-win-venv\envs\bavforest\lib\site-packages\sklearn\utils\_set_output.py:295, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     293 @wraps(f)
#     294 def wrapped(self, X, *args, **kwargs):
# --> 295     data_to_wrap = f(self, X, *args, **kwargs)
#     296     if isinstance(data_to_wrap, tuple):
#     297         # only wrap the first output for cross decomposition
#     298         return_tuple = (
#     299             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     300             *data_to_wrap[1:],
#     301         )
#
# File c:\Users\garov\.pyenv-win-venv\envs\bavforest\lib\site-packages\sklearn\base.py:1474, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1467     estimator._validate_params()
#    1469 with config_context(
#    1470     skip_parameter_validation=(
#    1471         prefer_skip_nested_validation or global_skip_validation
#    1472     )
#    1473 ):
# -> 1474     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\garov\.pyenv-win-venv\envs\bavforest\lib\site-packages\sklearn\compose\_column_transformer.py:906, in ColumnTransformer.fit_transform(self, X, y, **params)
#     903 self._validate_transformers()
#     904 n_samples = _num_samples(X)
# --> 906 self._validate_column_callables(X)
#     907 self._validate_remainder(X)
#     909 if _routing_enabled():
#
# File c:\Users\garov\.pyenv-win-venv\envs\bavforest\lib\site-packages\sklearn\compose\_column_transformer.py:496, in ColumnTransformer._validate_column_callables(self, X)
#     494         columns = columns(X)
#     495     all_columns.append(columns)
# --> 496     transformer_to_input_indices[name] = _get_column_indices(X, columns)
#     498 self._columns = all_columns
#     499 self._transformer_to_input_indices = transformer_to_input_indices
#
# File c:\Users\garov\.pyenv-win-venv\envs\bavforest\lib\site-packages\sklearn\utils\__init__.py:507, in _get_column_indices(X, key)
#     505         col_idx = all_columns.get_loc(col)
#     506         if not isinstance(col_idx, numbers.Integral):
# --> 507             raise ValueError(
#     508                 f"Selected columns, {columns}, are not unique in dataframe"
#     509             )
#     510         column_indices.append(col_idx)
#     512 except KeyError as e:
#
# ValueError: Selected columns, ['Wochenende', 'Laubfärbung', 'Schulferien_Bayern', 'Schulferien_CZ', 'Feiertag_Bayern', 'Feiertag_CZ', 'HEH_geoeffnet', 'HZW_geoeffnet', 'WGM_geoeffnet', 'Lusenschutzhaus_geoeffnet', 'Racheldiensthuette_geoeffnet', 'Falkensteinschutzhaus_geoeffnet', 'Schwellhaeusl_geoeffnet', 'Schulferien_CZ'], are not unique in dataframe

# %%
# Specify the folder path where you want to save the file
folder_path = r'C:\Users\garov\OneDrive\Documents\GitHub\bavarian-forest-visitor-monitoring-dssgx-24\outputs\Cleaned Data'

# Combine the folder path and file name
file_path = f'{folder_path}/rotated_sensors_data.csv'

# Write the final DataFrame to a CSV file in the specified folder
df_final_sub.to_csv(file_path, index=False, encoding='utf-8')
